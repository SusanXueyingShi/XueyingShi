# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
GS=pd.read_csv('GS_2006-01-01_to_2018-01-01.csv')
JPM=pd.read_csv('JPM_2006-01-01_to_2018-01-01.csv')
GS['GS_cap'] = GS['Close']*GS['Volume']/ 1e9
JPM['JPM_cap'] = JPM['Close']*JPM['Volume']/ 1e9
bank = GS.merge(JPM, how='inner', on='Date')
bank['Year'] = pd.DatetimeIndex(bank['Date']).year
bank = bank[['Year', 'GS_cap', 'JPM_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(bank['Date'], bank['GS_cap'], 'b-', label = 'Goldman Sachs')
plt.plot(bank['Date'], bank['JPM_cap'], 'r-', label = 'JPMorgan Chase')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of Goldman Sachs and JPMorgan Chase')
plt.legend();
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
# Out:
# ([<matplotlib.axis.XTick at 0x1a46b2e198>,
# ...
#  <a list of 12 Text xticklabel objects>)

# %%
CSCO=pd.read_csv('CSCO_2006-01-01_to_2018-01-01.csv')
INTC=pd.read_csv('INTC_2006-01-01_to_2018-01-01.csv')
CSCO['CSCO_cap'] = CSCO['Close']*CSCO['Volume']/ 1e9
INTC['INTC_cap'] = INTC['Close']*INTC['Volume']/ 1e9
techhardware = CSCO.merge(INTC,how='inner', on='Date')
techhardware['Year'] = pd.DatetimeIndex(techhardware['Date']).year
techhardware = techhardware[['Year', 'CSCO_cap', 'INTC_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(techhardware['Date'], techhardware['CSCO_cap'], 'b-', label = 'Cisco')
plt.plot(techhardware['Date'], techhardware['INTC_cap'], 'r-', label = 'Intel')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of Cisco and Intel')
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
plt.legend();

# %%
AMZ=pd.read_csv('AMZN_2006-01-01_to_2018-01-01.csv')
GOOGL=pd.read_csv('GOOGL_2006-01-01_to_2018-01-01.csv')
AMZ['AMZ_cap'] = AMZ['Close']*AMZ['Volume']/ 1e9
GOOGL['GOOGL_cap'] =GOOGL['Close']*GOOGL['Volume']/ 1e9
internet = AMZ.merge(GOOGL,how='inner', on='Date')
internet['Year'] = pd.DatetimeIndex(internet['Date']).year
internet = internet[['Year', 'AMZ_cap', 'GOOGL_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(internet['Date'], internet['AMZ_cap'], 'b-', label = 'Amazon')
plt.plot(internet['Date'], internet['GOOGL_cap'], 'r-', label = 'Google')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of Google and Amazon')
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
plt.legend();

# %%
IBM=pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv')
AAPL=pd.read_csv('AAPL_2006-01-01_to_2018-01-01.csv')
MSFT=pd.read_csv('MSFT_2006-01-01_to_2018-01-01.csv')
IBM['IBM_cap'] = IBM['Close']*IBM['Volume']/ 1e9
AAPL['AAPL_cap'] = AAPL['Close']*AAPL['Volume']/ 1e9
MSFT['MSFT_cap'] = MSFT['Close']*MSFT['Volume']/ 1e9
tech= IBM.merge(MSFT, how='inner', on='Date').merge(AAPL, how='inner', on='Date')
tech['Year'] = pd.DatetimeIndex(tech['Date']).year
tech= tech[['Year', 'IBM_cap', 'MSFT_cap','AAPL_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(tech['Date'], tech['IBM_cap'], 'b-', label = 'IBM')
plt.plot(tech['Date'], tech['AAPL_cap'], 'r-', label = 'Apple')
plt.plot(tech['Date'], tech['MSFT_cap'], 'g-', label = 'Microsoft')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of IBM, Apple and Microsoft')
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
plt.legend();

# %%
UTX=pd.read_csv('UTX_2006-01-01_to_2018-01-01.csv')
BOE=pd.read_csv('BA_2006-01-01_to_2018-01-01.csv')
UTX['UTX_cap'] = UTX['Close']*UTX['Volume']/ 1e9
BOE['BOE_cap'] = BOE['Close']*BOE['Volume']/ 1e9
aircraft = UTX.merge(BOE,how='inner', on='Date')
aircraft['Year'] = pd.DatetimeIndex(aircraft['Date']).year
aircraft = aircraft[['Year', 'UTX_cap', 'BOE_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(aircraft['Date'], aircraft['UTX_cap'], 'b-', label = 'United Technologies Corporation')
plt.plot(aircraft['Date'], aircraft['BOE_cap'], 'r-', label = 'Boeing')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of United Technologies Corporation and Boeing')
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
plt.legend();

# %%
GE=pd.read_csv('GE_2006-01-01_to_2018-01-01.csv')
MMM=pd.read_csv('MMM_2006-01-01_to_2018-01-01.csv')
GE['GE_cap']=GE['Close']*GE['Volume']/ 1e9
MMM['MMM_cap'] = MMM['Close']*MMM['Volume']/ 1e9
manufacturing = GE.merge(MMM,how='inner', on='Date')
manufacturing['Year'] = pd.DatetimeIndex(manufacturing['Date']).year
manufacturing = manufacturing[['Year', 'GE_cap', 'MMM_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(manufacturing['Date'], manufacturing['GE_cap'], 'b-', label = 'General Electric')
plt.plot(manufacturing['Date'], manufacturing['MMM_cap'], 'r-', label = '3M')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of General Electric and 3M')
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
plt.legend();

# %%
PFE=pd.read_csv('PFE_2006-01-01_to_2018-01-01.csv')
MRK=pd.read_csv('MRK_2006-01-01_to_2018-01-01.csv')
PFE['PFE_cap']=PFE['Close']*PFE['Volume']/ 1e9
MRK['MRK_cap'] = MRK['Close']*MRK['Volume']/ 1e9
pharmaceutical = PFE.merge(MRK,how='inner', on='Date')
pharmaceutical['Year'] = pd.DatetimeIndex(pharmaceutical['Date']).year
pharmaceutical = pharmaceutical[['Year', 'PFE_cap', 'MRK_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(pharmaceutical['Date'], pharmaceutical['PFE_cap'], 'b-', label = 'Pfizer')
plt.plot(pharmaceutical['Date'], pharmaceutical['MRK_cap'], 'r-', label = 'Merck & Co.')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of Pfizer and Merck & Co.')
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
plt.legend();

# %%
XOM=pd.read_csv('XOM_2006-01-01_to_2018-01-01.csv')
CVX=pd.read_csv('CVX_2006-01-01_to_2018-01-01.csv')
XOM['XOM_cap'] = XOM['Close']*XOM['Volume']/ 1e9
CVX['CVX_cap'] = CVX['Close']*CVX['Volume']/ 1e9
oil = XOM.merge(CVX, how='inner', on='Date')
oil['Year'] = pd.DatetimeIndex(oil['Date']).year
oil = oil[['Year', 'XOM_cap', 'CVX_cap','Date']]
date = oil.Date.astype('O')



industries = oil.merge(aircraft, how='inner', on='Date').merge(bank, how='inner', on='Date').merge(tech, how='inner', on='Date').merge(techhardware, how='inner', on='Date').merge(internet, how='inner', on='Date').merge(pharmaceutical, how='inner', on='Date').merge(manufacturing, how='inner', on='Date').merge(insurance, how='inner', on='Date').merge(consumergoods, how='inner', on='Date')
industries = industries[['XOM_cap','JPM_cap','CSCO_cap','GE_cap','BOE_cap','AMZ_cap','PFE_cap','PG_cap','UNH_cap']]

sns.pairplot(industries)

# %% [markdown]
# test linear Correlation between XOM and PG

# %%
sns.lmplot(x='XOM_cap',y='PG_cap',data=industries)

# %%
PG=pd.read_csv('PG_2006-01-01_to_2018-01-01.csv')
JNJ=pd.read_csv('JNJ_2006-01-01_to_2018-01-01.csv')
PG['PG_cap']=PG['Close']*PG['Volume']/ 1e9
JNJ['JNJ_cap'] = JNJ['Close']*JNJ['Volume']/ 1e9
consumergoods = PG.merge(JNJ,how='inner', on='Date')
consumergoods['Year'] = pd.DatetimeIndex(consumergoods['Date']).year
consumergoods = consumergoods[['Year', 'PG_cap', 'JNJ_cap','Date']]
plt.figure(figsize=(10, 8))
plt.plot(oil['Date'], oil['XOM_cap'], 'g-', label = 'ExxonMobil')
plt.plot(oil['Date'], oil['CVX_cap'], 'y-', label = 'Chevron Corporation')
plt.plot(consumergoods['Date'], consumergoods['PG_cap'], 'b-', label = 'Procter & Gamble')
plt.plot(consumergoods['Date'], consumergoods['JNJ_cap'], 'r-', label = 'Johnson & Johnson')
plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of Procter & Gamble and Johnson & Johnson')
plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
plt.legend();

# %%
#UNH=pd.read_csv('UNH_2006-01-01_to_2018-01-01.csv')
#TRV=pd.read_csv('TRV_2006-01-01_to_2018-01-01.csv')
#UNH['UNH_cap']=UNH['Close']*UNH['Volume']/ 1e9
#TRV['TRV_cap'] = TRV['Close']*TRV['Volume']/ 1e9
#insurance = UNH.merge(TRV,how='inner', on='Date')
#insurance['Year'] = pd.DatetimeIndex(insurance['Date']).year
#insurance = insurance[['Year', 'UNH_cap', 'TRV_cap','Date']]
#plt.figure(figsize=(10, 8))

#plt.plot(insurance['Date'], insurance['UNH_cap'], 'b-', label = 'UnitedHealth Group')
#plt.plot(insurance['Date'], insurance['TRV_cap'], 'r-', label = 'The Travelers Companies')
#datemin = datetime.date(datetime.date(date.min().year), 1, 1)
#datemax = datetime.date(datetime.date(2018) + 1, 1, 1)
#ax.set_xlim(datemin, datemax)


#plt.xlabel('Year'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of UnitedHealth Group and The Travelers Companies')
#plt.xticks(np.arange(0,oil.shape[0],252),np.arange(2006,2018,1))
#plt.legend();

# %%
#plt.figure(figsize=(10, 8))
#plt.plot(oil['Date'], oil['XOM_cap'], 'b-', label = 'ExxonMobil')
#plt.plot(oil['Date'], oil['CVX_cap'], 'r-', label = 'Chevron Corporation')
#plt.xlabel('Date'); plt.ylabel('Market Cap (Billions $)'); plt.title('Market Cap of ExxonMobil and Chevron Corporation')
#plt.legend();
#plt.xticks(arange(13),('2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018'))
